# %%
# %pip install --upgrade pip
# %pip install pytrends
# Out:
# Requirement already satisfied: pip in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (23.3.1)
# Collecting pip
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# WARNING: Error parsing requirements for torch: [Errno 2] No such file or directory: '/Users/bob/opt/anaconda3/lib/python3.9/site-packages/torch-2.2.2.dist-info/METADATA'
# WARNING: Error parsing requirements for transformers: [Errno 2] No such file or directory: '/Users/bob/opt/anaconda3/lib/python3.9/site-packages/transformers-4.57.3.dist-info/METADATA'
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.3.1
#     Uninstalling pip-23.3.1:
#       Successfully uninstalled pip-23.3.1
# Successfully installed pip-25.3
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pytrends in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: pandas>=0.25 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (2.3.3)
# Requirement already satisfied: lxml in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pytrends) (4.9.1)
# Requirement already satisfied: numpy>=1.22.4 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.25->pytrends) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bob/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.0->pytrends) (2022.9.24)
# WARNING: Error parsing dependencies of torch: [Errno 2] No such file or directory: '/Users/bob/opt/anaconda3/lib/python3.9/site-packages/torch-2.2.2.dist-info/METADATA'
# WARNING: Error parsing dependencies of transformers: [Errno 2] No such file or directory: '/Users/bob/opt/anaconda3/lib/python3.9/site-packages/transformers-4.57.3.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
# Out:
# /Users/bob/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/bob/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
trends = TrendReq()

# %%
trends.build_payload(kw_list = ["Machine learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine learning", ascending=False)
data = data.head(10)

# %%
data
# Out:
#              Machine learning
# geoName
# China                     100
# Ethiopia                   57
# Singapore                  55
# India                      49
# Tunisia                    35
# Sri Lanka                  34
# Pakistan                   32
# Hong Kong                  31
# Nepal                      29
# South Korea                29

# %%
data.reset_index().plot(x="geoName", y="Machine learning", figsize=(12, 6) , kind = "bar")
plt.style.use("fivethirtyeight")
plt.show()

# %%
data = TrendReq(hl = 'en-US', tz = 360)
data.build_payload(kw_list = ['Machine Learning'])
data =  data.interest_over_time()

fig , ax = plt.subplots(figsize = (20,10))
data["Machine Learning"].plot()
plt.style.use('fivethirtyeight')
plt.title('Machine Learning Google Trends', fontweight = 'bold')
plt.xlabel("Year")
plt.ylabel("Interest")
plt.show()
# Out:
# /Users/bob/opt/anaconda3/lib/python3.9/site-packages/pytrends/request.py:260: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.fillna(False)
